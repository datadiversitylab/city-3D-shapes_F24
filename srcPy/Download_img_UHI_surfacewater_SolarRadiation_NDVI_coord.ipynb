# %%
# !pip install geemap
# Out:
# Requirement already satisfied: geemap in c:\users\pradn\anaconda3\lib\site-packages (0.34.5)
# Requirement already satisfied: bqplot in c:\users\pradn\anaconda3\lib\site-packages (from geemap) (0.12.43)
# Requirement already satisfied: colour in c:\users\pradn\anaconda3\lib\site-packages (from geemap) (0.1.5)
# Requirement already satisfied: earthengine-api>=1.0.0 in c:\users\pradn\anaconda3\lib\site-packages (from geemap) (1.1.1)
# Requirement already satisfied: eerepr>=0.0.4 in c:\users\pradn\anaconda3\lib\site-packages (from geemap) (0.0.4)
# Requirement already satisfied: folium>=0.17.0 in c:\users\pradn\anaconda3\lib\site-packages (from geemap) (0.17.0)
# Requirement already satisfied: geocoder in c:\users\pradn\anaconda3\lib\site-packages (from geemap) (1.38.1)
# Requirement already satisfied: ipyevents in c:\users\pradn\anaconda3\lib\site-packages (from geemap) (2.0.2)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in c:\users\pradn\anaconda3\lib\site-packages (from geemap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.19.2 in c:\users\pradn\anaconda3\lib\site-packages (from geemap) (0.19.2)
# Requirement already satisfied: ipytree in c:\users\pradn\anaconda3\lib\site-packages (from geemap) (0.2.2)
# Requirement already satisfied: matplotlib in c:\users\pradn\anaconda3\lib\site-packages (from geemap) (3.8.4)
# Requirement already satisfied: numpy in c:\users\pradn\anaconda3\lib\site-packages (from geemap) (1.26.4)
# Requirement already satisfied: pandas in c:\users\pradn\anaconda3\lib\site-packages (from geemap) (2.2.2)
# Requirement already satisfied: plotly in c:\users\pradn\anaconda3\lib\site-packages (from geemap) (5.22.0)
# Requirement already satisfied: pyperclip in c:\users\pradn\anaconda3\lib\site-packages (from geemap) (1.9.0)
# Requirement already satisfied: pyshp>=2.3.1 in c:\users\pradn\anaconda3\lib\site-packages (from geemap) (2.3.1)
# Requirement already satisfied: python-box in c:\users\pradn\anaconda3\lib\site-packages (from geemap) (7.2.0)
# Requirement already satisfied: scooby in c:\users\pradn\anaconda3\lib\site-packages (from geemap) (0.10.0)
# Requirement already satisfied: setuptools in c:\users\pradn\appdata\roaming\python\python312\site-packages (from geemap) (75.3.0)
# Requirement already satisfied: google-cloud-storage in c:\users\pradn\anaconda3\lib\site-packages (from earthengine-api>=1.0.0->geemap) (2.18.2)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\pradn\anaconda3\lib\site-packages (from earthengine-api>=1.0.0->geemap) (2.147.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\pradn\anaconda3\lib\site-packages (from earthengine-api>=1.0.0->geemap) (2.35.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\pradn\anaconda3\lib\site-packages (from earthengine-api>=1.0.0->geemap) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\pradn\anaconda3\lib\site-packages (from earthengine-api>=1.0.0->geemap) (0.22.0)
# Requirement already satisfied: requests in c:\users\pradn\appdata\roaming\python\python312\site-packages (from earthengine-api>=1.0.0->geemap) (2.32.3)
# Requirement already satisfied: branca>=0.6.0 in c:\users\pradn\anaconda3\lib\site-packages (from folium>=0.17.0->geemap) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\pradn\anaconda3\lib\site-packages (from folium>=0.17.0->geemap) (3.1.4)
# Requirement already satisfied: xyzservices in c:\users\pradn\anaconda3\lib\site-packages (from folium>=0.17.0->geemap) (2022.9.0)
# Requirement already satisfied: ipywidgets in c:\users\pradn\anaconda3\lib\site-packages (from ipyfilechooser>=0.6.0->geemap) (7.8.1)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in c:\users\pradn\anaconda3\lib\site-packages (from ipyleaflet>=0.19.2->geemap) (0.19.2)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\pradn\anaconda3\lib\site-packages (from ipyleaflet>=0.19.2->geemap) (0.2.1)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\pradn\anaconda3\lib\site-packages (from bqplot->geemap) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pradn\anaconda3\lib\site-packages (from pandas->geemap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pradn\anaconda3\lib\site-packages (from pandas->geemap) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pradn\anaconda3\lib\site-packages (from pandas->geemap) (2023.3)
# Requirement already satisfied: click in c:\users\pradn\anaconda3\lib\site-packages (from geocoder->geemap) (8.1.7)
# Requirement already satisfied: future in c:\users\pradn\anaconda3\lib\site-packages (from geocoder->geemap) (1.0.0)
# Requirement already satisfied: ratelim in c:\users\pradn\anaconda3\lib\site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: six in c:\users\pradn\appdata\roaming\python\python312\site-packages (from geocoder->geemap) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pradn\anaconda3\lib\site-packages (from matplotlib->geemap) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\pradn\anaconda3\lib\site-packages (from matplotlib->geemap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pradn\anaconda3\lib\site-packages (from matplotlib->geemap) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pradn\anaconda3\lib\site-packages (from matplotlib->geemap) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\pradn\appdata\roaming\python\python312\site-packages (from matplotlib->geemap) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\pradn\anaconda3\lib\site-packages (from matplotlib->geemap) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pradn\anaconda3\lib\site-packages (from matplotlib->geemap) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\pradn\anaconda3\lib\site-packages (from plotly->geemap) (8.2.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\pradn\anaconda3\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (2.20.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\pradn\anaconda3\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\pradn\anaconda3\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pradn\anaconda3\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pradn\anaconda3\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (4.9)
# Requirement already satisfied: comm>=0.1.3 in c:\users\pradn\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\pradn\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\pradn\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\pradn\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.25.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\pradn\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pradn\appdata\roaming\python\python312\site-packages (from jinja2>=2.9->folium>=0.17.0->geemap) (3.0.2)
# Requirement already satisfied: colorama in c:\users\pradn\anaconda3\lib\site-packages (from click->geocoder->geemap) (0.4.6)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\pradn\anaconda3\lib\site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.7.2 in c:\users\pradn\anaconda3\lib\site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\pradn\anaconda3\lib\site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap) (1.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pradn\appdata\roaming\python\python312\site-packages (from requests->earthengine-api>=1.0.0->geemap) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pradn\appdata\roaming\python\python312\site-packages (from requests->earthengine-api>=1.0.0->geemap) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pradn\appdata\roaming\python\python312\site-packages (from requests->earthengine-api>=1.0.0->geemap) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pradn\appdata\roaming\python\python312\site-packages (from requests->earthengine-api>=1.0.0->geemap) (2024.8.30)
# Requirement already satisfied: decorator in c:\users\pradn\anaconda3\lib\site-packages (from ratelim->geocoder->geemap) (5.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\pradn\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (1.65.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in c:\users\pradn\appdata\roaming\python\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (5.28.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\pradn\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (1.24.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\pradn\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\pradn\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\pradn\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\pradn\appdata\roaming\python\python312\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\pradn\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\pradn\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (0.4.8)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\pradn\anaconda3\lib\site-packages (from widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (7.0.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\pradn\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\pradn\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\pradn\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in c:\users\pradn\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\pradn\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\pradn\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.4.1)
# Requirement already satisfied: wcwidth in c:\users\pradn\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.5)
# Requirement already satisfied: executing in c:\users\pradn\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\pradn\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\pradn\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\pradn\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\pradn\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (21.3.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\pradn\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\pradn\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\pradn\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\pradn\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\pradn\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (7.10.0)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\pradn\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.9.2)
# Requirement already satisfied: overrides>=5.0 in c:\users\pradn\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\pradn\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\pradn\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in c:\users\pradn\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\pradn\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\pradn\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\pradn\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\pradn\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.4)
# Requirement already satisfied: ipykernel in c:\users\pradn\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\pradn\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\pradn\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\pradn\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\pradn\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.19.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\pradn\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\pradn\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\pradn\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\pradn\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\pradn\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\pradn\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\pradn\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\pradn\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (305.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\pradn\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\pradn\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\pradn\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\pradn\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\pradn\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\pradn\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\pradn\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\pradn\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\pradn\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\pradn\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\pradn\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\pradn\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\pradn\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.16.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\pradn\anaconda3\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.6.7)
# Requirement already satisfied: nest-asyncio in c:\users\pradn\anaconda3\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.6.0)
# Requirement already satisfied: psutil in c:\users\pradn\anaconda3\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.9.0)
# Requirement already satisfied: webencodings in c:\users\pradn\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.5.1)
# Requirement already satisfied: fqdn in c:\users\pradn\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\pradn\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\pradn\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.1)
# Requirement already satisfied: uri-template in c:\users\pradn\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\pradn\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\pradn\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pradn\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.5)
# Requirement already satisfied: pycparser in c:\users\pradn\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\pradn\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.2.3)

# %%
# !pip install geedim
# Out:
# Requirement already satisfied: geedim in c:\users\pradn\anaconda3\lib\site-packages (1.8.1)
# Requirement already satisfied: numpy>=1.19 in c:\users\pradn\anaconda3\lib\site-packages (from geedim) (1.26.4)
# Requirement already satisfied: rasterio>=1.3 in c:\users\pradn\anaconda3\lib\site-packages (from geedim) (1.4.0)
# Requirement already satisfied: click>=8 in c:\users\pradn\anaconda3\lib\site-packages (from geedim) (8.1.7)
# Requirement already satisfied: tqdm>=4.6 in c:\users\pradn\anaconda3\lib\site-packages (from geedim) (4.66.4)
# Requirement already satisfied: earthengine-api>=0.1.2 in c:\users\pradn\anaconda3\lib\site-packages (from geedim) (1.1.1)
# Requirement already satisfied: requests>=2.2 in c:\users\pradn\appdata\roaming\python\python312\site-packages (from geedim) (2.32.3)
# Requirement already satisfied: tabulate>=0.8 in c:\users\pradn\anaconda3\lib\site-packages (from geedim) (0.9.0)
# Requirement already satisfied: colorama in c:\users\pradn\anaconda3\lib\site-packages (from click>=8->geedim) (0.4.6)
# Requirement already satisfied: google-cloud-storage in c:\users\pradn\anaconda3\lib\site-packages (from earthengine-api>=0.1.2->geedim) (2.18.2)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\pradn\anaconda3\lib\site-packages (from earthengine-api>=0.1.2->geedim) (2.147.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\pradn\anaconda3\lib\site-packages (from earthengine-api>=0.1.2->geedim) (2.35.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\pradn\anaconda3\lib\site-packages (from earthengine-api>=0.1.2->geedim) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\pradn\anaconda3\lib\site-packages (from earthengine-api>=0.1.2->geedim) (0.22.0)
# Requirement already satisfied: affine in c:\users\pradn\anaconda3\lib\site-packages (from rasterio>=1.3->geedim) (2.4.0)
# Requirement already satisfied: attrs in c:\users\pradn\anaconda3\lib\site-packages (from rasterio>=1.3->geedim) (23.1.0)
# Requirement already satisfied: certifi in c:\users\pradn\appdata\roaming\python\python312\site-packages (from rasterio>=1.3->geedim) (2024.8.30)
# Requirement already satisfied: cligj>=0.5 in c:\users\pradn\anaconda3\lib\site-packages (from rasterio>=1.3->geedim) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\pradn\anaconda3\lib\site-packages (from rasterio>=1.3->geedim) (1.1.1)
# Requirement already satisfied: pyparsing in c:\users\pradn\anaconda3\lib\site-packages (from rasterio>=1.3->geedim) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pradn\appdata\roaming\python\python312\site-packages (from requests>=2.2->geedim) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pradn\appdata\roaming\python\python312\site-packages (from requests>=2.2->geedim) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pradn\appdata\roaming\python\python312\site-packages (from requests>=2.2->geedim) (2.2.3)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\pradn\anaconda3\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.2->geedim) (2.20.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\pradn\anaconda3\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.2->geedim) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\pradn\anaconda3\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.2->geedim) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pradn\anaconda3\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.2->geedim) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pradn\anaconda3\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.2->geedim) (4.9)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\pradn\anaconda3\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.2->geedim) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.7.2 in c:\users\pradn\anaconda3\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.2->geedim) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\pradn\anaconda3\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.2->geedim) (1.6.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\pradn\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.2->geedim) (1.65.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in c:\users\pradn\appdata\roaming\python\python312\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.2->geedim) (5.28.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\pradn\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.2->geedim) (1.24.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\pradn\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=0.1.2->geedim) (0.4.8)

# %%
import ee
import geemap
import os
import geedim

# %%
ee.Authenticate()
ee.Initialize(project='ee-pradnyauoa')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# *** Earth Engine *** Share your feedback by taking our Annual Developer Satisfaction Survey: https://google.qualtrics.com/jfe/form/SV_0JLhFqfSY1uiEaW?source=Init

# %%
Map = geemap.Map()
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %%
cty = ee.FeatureCollection('projects/ee-pradnyauoa/assets/data')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
roi = cty.geometry()
print(roi)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ee.Geometry({
#   "functionInvocationValue": {
#     "functionName": "Collection.geometry",
#     "arguments": {
#       "collection": {
#         "functionInvocationValue": {
#           "functionName": "Collection.loadTable",
#           "arguments": {
#             "tableId": {
#               "constantValue": "projects/ee-pradnyauoa/assets/data"
#             }
#           }
#         }
#       }
#     }
#   }
# })

# %%
import pandas as pd

citylist= list()


def get_centroid(feature):
  keepfld = ['NAME_CONVE',]
  centroid = feature.geometry().centroid()
  return ee.Feature(centroid).copyProperties(feature, keepfld)

cty = ee.FeatureCollection('projects/ee-pradnyauoa/assets/data')
tbl = cty  #cty    #.filter(filterInside)
ftrs = tbl.toList(tbl.size())
fld = 'name_conve'
  # Print the specific property of each feature
ctylst=list()

if os.path.isfile('City_coordinates.csv'):
    df = pd.read_csv('City_coordinates.csv', encoding="utf-8")
    ctylst= df.values.tolist()
else:
    ctylst= list()


for i in range(0, ftrs.size().getInfo()):
    if i< len(ctylst):
        continue
    else:
        print(i)
    
    feature = ee.Feature(ftrs.get(i))
    cent = get_centroid(feature)
    ctycoord = cent.getInfo()['geometry']['coordinates']   
    ctynm = feature.get(fld).getInfo()
    ctylst.append([ctynm,ctycoord[0], ctycoord[1], ctycoord ])
    print(i, ctynm, ctycoord)
    if (i%25== 0):
        df = pd.DataFrame(ctylst, columns=['city', 'longitude','latitude','coordinates'])
        df.to_csv('City_coordinates.csv', index=False, encoding="utf-8")

print(len(ctylst))
#citylist.append(ctylst )

df = pd.DataFrame(ctylst, columns=['city', 'longitude','latitude','coordinates'])
df.to_csv('City_coordinates.csv', index=False, encoding="utf-8")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 6018

# %%
df = pd.DataFrame(ctylst, columns=['city', 'coordinates'])
df.to_csv('City_coordinates.csv', index=False, encoding="utf-8")

# %%
for i in range(0, 100):
    if (i%10== 0):
        print(i)
    else:
        print(i%10)
